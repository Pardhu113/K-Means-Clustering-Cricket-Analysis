# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('c:/Users/A S H B O R N/Downloads/ODI data.csv',encoding='latin1')
df.head()
# Out:
#    Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0           0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1           1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2           2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3           3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4           4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
#
#      HS    Ave     BF     SR 100  50   0  Unnamed: 13
# 0  200*  44.83  21367  86.23  49  96  20          NaN
# 1   169  41.98  18048  78.86  25  93  15          NaN
# 2   164  42.03  17046  80.39  30  82  20          NaN
# 3   189  32.36  14725   91.2  28  68  34          NaN
# 4   144  33.37  16020  78.96  19  77  28          NaN

# %% [markdown]
# # data cleaning

# %%
df.columns = df.columns.str.strip() \
                       .str.lower() \
                       .str.replace(" ", "_")

# %%
df
# Out:
#       unnamed:_0                       player       span  mat inns  no   runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2495          45              ZS Ansari (ENG)  2015-2015    1    -   -      -
# 2496          46         Ariful Haque (BDESH)  2018-2018    1    -   -      -
# 2497          47           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -
# 2498          48               MD Bailey (NZ)  1998-1998    1    -   -      -
# 2499          49               GR Beard (AUS)  1981-1981    2    -   -      -
#
# ...

# %%
df = df.loc[:, ~df.columns.str.contains("^unnamed")]

# %%
df
# Out:
#                            player       span  mat inns  no   runs    hs  \
# 0            SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*
# 1     KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169
# 2            RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164
# 3         ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189
# 4      DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144
# ...                           ...        ...  ...  ...  ..    ...   ...
# 2495              ZS Ansari (ENG)  2015-2015    1    -   -      -     -
# 2496         Ariful Haque (BDESH)  2018-2018    1    -   -      -     -
# 2497           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -     -
# 2498               MD Bailey (NZ)  1998-1998    1    -   -      -     -
# 2499               GR Beard (AUS)  1981-1981    2    -   -      -     -
#
#         ave     bf     sr 100  50   0
# 0     44.83  21367  86.23  49  96  20
# ...

# %%
(df == "-").sum()
df.replace("-", np.nan, inplace=True)
df.isnull().sum()
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\4219383962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace("-", np.nan, inplace=True)
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\4219383962.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# player    0
# span      0
# mat       0
# inns      0
# no        0
# runs      0
# hs        0
# ave       0
# bf        0
# sr        0
# 100       0
# 50        0
# 0         0
# dtype: int64

# %%
df
# Out:
#                            player       span  mat inns  no   runs    hs  \
# 0            SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*
# 1     KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169
# 2            RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164
# 3         ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189
# 4      DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144
# ...                           ...        ...  ...  ...  ..    ...   ...
# 2484               GS Sobers (WI)  1973-1973    1    1   0      0     0
# 2485           Tanvir Mehdi (PAK)  1992-1992    1    1   0      0     0
# 2487              R Walters (NAM)  2003-2003    2    2   0      0     0
# 2488           CM Willoughby (SA)  2000-2003    3    2   0      0     0
# 2489        Zakir Hossain (BDESH)  1998-1998    1    1   0      0     0
#
#         ave     bf     sr 100  50   0
# 0     44.83  21367  86.23  49  96  20
# ...

# %%
# calculate experience
df[['stat','end']]=df['span'].str.split('-',expand=True)
df['stat']=df['stat'].astype(int)
df['end']=df['end'].astype(int)
df['experience']=df['end']-df['stat']
df.head()
# Out:
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\2615895924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['stat','end']]=df['span'].str.split('-',expand=True)
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\2615895924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['stat','end']]=df['span'].str.split('-',expand=True)
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\2615895924.py:3: SettingWithCopyWarning:
# ...

# %%
# delete unnecessary columns now
df.drop(columns=['player','span','stat','end'],inplace=True)
# Out:
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\1821766992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['player','span','stat','end'],inplace=True)

# %%
df
# Out:
#       mat inns  no   runs    hs    ave     bf     sr 100  50   0  experience
# 0     463  452  41  18426  200*  44.83  21367  86.23  49  96  20          23
# 1     404  380  41  14234   169  41.98  18048  78.86  25  93  15          15
# 2     375  365  39  13704   164  42.03  17046  80.39  30  82  20          17
# 3     445  433  18  13430   189  32.36  14725   91.2  28  68  34          22
# 4     448  418  39  12650   144  33.37  16020  78.96  19  77  28          17
# ...   ...  ...  ..    ...   ...    ...    ...    ...  ..  ..  ..         ...
# 2484    1    1   0      0     0   0.00      6   0.00   0   0   1           0
# 2485    1    1   0      0     0   0.00      5   0.00   0   0   1           0
# 2487    2    2   0      0     0   0.00      5   0.00   0   0   2           0
# 2488    3    2   0      0     0   0.00      4   0.00   0   0   2           3
# 2489    1    1   0      0     0   0.00      1   0.00   0   0   1           0
#
# [2369 rows x 12 columns]

# %%
# type casting the columns to appropriate data types
df["hs"] = df["hs"].astype(str).str.replace("*", "", regex=False)
df["hs"] = pd.to_numeric(df["hs"], errors="coerce")
# Out:
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\2840854851.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["hs"] = df["hs"].astype(str).str.replace("*", "", regex=False)
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\2840854851.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["hs"] = pd.to_numeric(df["hs"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2369 entries, 0 to 2489
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   mat         2369 non-null   float64
#  1   inns        2369 non-null   float64
#  2   no          2369 non-null   float64
#  3   runs        2369 non-null   float64
#  4   hs          2369 non-null   int64
#  5   ave         2369 non-null   object
#  6   bf          2369 non-null   object
#  7   sr          2369 non-null   object
#  8   100         2369 non-null   object
#  9   50          2369 non-null   object
#  10  0           2369 non-null   object
#  11  experience  2369 non-null   int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 240.6+ KB

# %%
df.columns
# Out:
# Index(['mat', 'inns', 'no', 'runs', 'hs', 'ave', 'bf', 'sr', '100', '50', '0',
#        'experience'],
#       dtype='object')

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2369 entries, 0 to 2489
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   mat         2369 non-null   float64
#  1   inns        2369 non-null   float64
#  2   no          2369 non-null   float64
#  3   runs        2369 non-null   float64
#  4   hs          2369 non-null   int64
#  5   ave         2369 non-null   float64
#  6   bf          2369 non-null   float64
#  7   sr          2369 non-null   float64
#  8   100         2369 non-null   float64
#  9   50          2369 non-null   float64
#  10  0           2369 non-null   float64
#  11  experience  2369 non-null   int64
# dtypes: float64(10), int64(2)
# memory usage: 240.6 KB
# C:\Users\A S H B O R N\AppData\Local\Temp\ipykernel_24620\99417610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # standard scalar - to equalize the dataset format

# %%
# standardizing the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)

# %%
scaled_df
# Out:
# array([[ 7.07649678,  8.05497719,  3.69664373, ...,  9.14643204,
#          4.46395506,  4.1625078 ],
#        [ 6.09167008,  6.67726575,  3.69664373, ...,  8.84898132,
#          3.18119068,  2.36952067],
#        [ 5.60760271,  6.39024254,  3.48718789, ...,  7.75832864,
#          4.46395506,  2.81776745],
#        ...,
#        [-0.61850507, -0.55571927, -0.59720115, ..., -0.37199129,
#         -0.1539967 , -0.9923302 ],
#        [-0.6018131 , -0.55571927, -0.59720115, ..., -0.37199129,
#         -0.1539967 , -0.31996003],
#        [-0.63519705, -0.57485415, -0.59720115, ..., -0.37199129,
#         -0.41054958, -0.9923302 ]], shape=(2369, 12))

# %%
scaled_df=pd.DataFrame(scaled_df,columns=df.columns)
scaled_df.head()
# Out:
#         mat      inns        no       runs        hs       ave        bf  \
# 0  7.076497  8.054977  3.696644  10.736356  3.402219  2.073096  9.704142
# 1  6.091670  6.677266  3.696644   8.195850  2.699331  1.850487  8.126578
# 2  5.607603  6.390243  3.487188   7.874651  2.585962  1.854393  7.650314
# 3  6.776041  7.691414  1.287901   7.708597  3.152807  1.099085  6.547111
# 4  6.826117  7.404391  3.487188   7.235888  2.132486  1.177974  7.162642
#
#          sr        100        50         0  experience
# 0  0.892017  16.043121  9.146432  4.463955    4.162508
# 1  0.601816   8.061011  8.848981  3.181191    2.369521
# 2  0.662061   9.723950  7.758329  4.463955    2.817767
# 3  1.087716   9.058774  6.370225  8.055695    3.938384
# 4  0.605754   6.065483  7.262577  6.516378    2.817767

# %% [markdown]
# # model K-Means

# %%
# elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')   
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# k-means clustering
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = kmeans.fit_predict(scaled_df)
scaled_df['Cluster'] = y_kmeans
scaled_df.head()
# Out:
#         mat      inns        no       runs        hs       ave        bf  \
# 0  7.076497  8.054977  3.696644  10.736356  3.402219  2.073096  9.704142
# 1  6.091670  6.677266  3.696644   8.195850  2.699331  1.850487  8.126578
# 2  5.607603  6.390243  3.487188   7.874651  2.585962  1.854393  7.650314
# 3  6.776041  7.691414  1.287901   7.708597  3.152807  1.099085  6.547111
# 4  6.826117  7.404391  3.487188   7.235888  2.132486  1.177974  7.162642
#
#          sr        100        50         0  experience  Cluster
# 0  0.892017  16.043121  9.146432  4.463955    4.162508        3
# 1  0.601816   8.061011  8.848981  3.181191    2.369521        3
# 2  0.662061   9.723950  7.758329  4.463955    2.817767        3
# 3  1.087716   9.058774  6.370225  8.055695    3.938384        3
# 4  0.605754   6.065483  7.262577  6.516378    2.817767        3

# %%
# plotting the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=scaled_df.iloc[:, 0], y=scaled_df.iloc[:, 1], hue=scaled_df['Cluster'], palette='Set1')
plt.title('K-Means Clustering')
plt.show()

# %%
# plotly visualization

import plotly.express as px
fig = px.scatter_3d(scaled_df, x=scaled_df.columns[0], y=scaled_df.columns[1], z=scaled_df.columns[2],
                    color='Cluster', title='3D K-Means Clustering')
fig.show()

# %%
# plotly installation
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.9 MB 14.3 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.9 MB 13.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
# ...
